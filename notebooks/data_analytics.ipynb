# %%
import sqlite3
import pandas as pd

con=sqlite3.connect(r"C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\data\raw\ipl.db")
def q(sql):
    return pd.read_sql_query(sql,con)

# %%
def run_sql_file(path):
    with open(path, 'r') as f:
        script = f.read()
        con.executescript(script)
        con.commit()
        print('ran',path)

# %%
q("""
-- what is the strike rate of every batter in the death overs

SELECT batter,
ROUND(
    100.0 * SUM(batter_runs) / SUM(
        CASE
            WHEN is_wide_ball = 0 AND is_no_ball = 0 THEN 1
            ELSE 0
        END
    ),
    2
) AS strike_rate

FROM deliveries
WHERE over_number >= 15 AND is_super_over = 0
GROUP BY batter;""")
# Out:
#              batter  strike_rate
# 0    A Ashish Reddy       146.58
# 1          A Badoni       165.03
# 2        A Chandila        57.14
# 3          A Chopra        50.00
# 4       A Choudhary       125.00
# ..              ...          ...
# 637      Yash Dayal        50.00
# 638   Yashpal Singh       130.77
# 639   Yudhvir Singh       166.67
# 640    Yuvraj Singh       183.40
# 641          Z Khan       100.00
#
# [642 rows x 2 columns]

# %%
run_sql_file(r'C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\sql\09_analysis_views.sql

# %%
q("""
SELECT *
 FROM v_ball;
""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288046       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288047       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288048       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288049       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288050       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q(""" SELECT phase, count(*) FROM v_ball GROUP BY phase;""")
# Out:
#        phase  count(*)
# 0      Death     65488
# 1     Middle    132173
# 2  Powerplay     90390

# %%
run_sql_file(r'C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\sql\09_analysis_views.sql

# %%
q("""SELECT * FROM v_innings;""")
# Out:
#       match_id  innings                 batting_team  \
# 0       335982        1        Kolkata Knight Riders
# 1       335982        2  Royal Challengers Bangalore
# 2       335983        1          Chennai Super Kings
# 3       335983        2                 Punjab Kings
# 4       335984        1             Rajasthan Royals
# ...        ...      ...                          ...
# 2413   1529284        2          Sunrisers Hyderabad
# 2414   1529285        1  Royal Challengers Bangalore
# 2415   1529285        2               Gujarat Titans
# 2416   1529286        1             Rajasthan Royals
# 2417   1529286        2               Delhi Capitals
#
#                      bowling_team  runs  wickets  legal_balls
# 0     Royal Challengers Bangalore   222        3          120
# 1           Kolkata Knight Riders    82       10           91
# 2                    Punjab Kings   240        5          120
# 3             Chennai Super Kings   207        4          120
# ...

# %%
run_sql_file(r'C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\mhdlz\OneDrive\Desktop\project_3.1 - Sem--3\sql\09_analysis_views.sql

# %%
q("""
SELECT * FROM v_match_totals;""")
# Out:
#       match_id                                        venue_clean  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591                 Rajiv Gandhi International Stadium
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1182   1529282                               Arun Jaitley Stadium
# 1183   1529283  Maharaja Yadavindra Singh International Cricke...
# 1184   1529284                                   Wankhede Stadium
# 1185   1529285                              Narendra Modi Stadium
# 1186   1529286                             Sawai Mansingh Stadium
#
#           city_clean  season_year result                 match_winner  \
# 0          Bangalore         2008    win        Kolkata Knight Riders
# ...

# %%
q("""SELECT count(*) FROM v_match_totals;""")
# Out:
#    count(*)
# 0      1187

# %%
q("""SELECT COUNt(*) FROM v_innings ;""")
# Out:
#    COUNt(*)
# 0      2418

# %%
q("""SELECT phase,COUNT(*)FROM v_ball;""")
# Out:
#        phase  COUNT(*)
# 0  Powerplay    288051
